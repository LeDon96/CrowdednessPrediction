# %% [markdown]
# # Amsterdam Events Visualization

# %% [markdown]
# ## Imports

# %%
import pandas as pd

#Visualizations
import matplotlib.pyplot as plt
import descartes
import geopandas as gpd
from shapely.geometry import Point, Polygon

# %matplotlib inline

# %% [markdown]
# ## Import Files

# %%
#Full Events Dataset
events_df = pd.read_csv("../../../Data_thesis/Full_Datasets/Events.csv")

# %%
events_df.head()
# Out:
#          Date                Event   Latitude  Longtitude
# 0  2018-04-20  Springsnow Festival  52.372638    4.894106
# 1  2018-05-20  Springsnow Festival  52.372638    4.894106
# 2  2018-06-02     Holland Festival  52.361582    4.885479
# 3  2018-06-03     Holland Festival  52.361582    4.885479
# 4  2018-06-04     Holland Festival  52.361582    4.885479

# %%
#Full GVB dataset --> For Dates
gvb_df = pd.read_csv("../../../Data_thesis/Full_Datasets/GVB.csv")

# %%
#Map of Amsterdam
road_map = gpd.read_file("../../../Data_thesis/MapShapeFiles/roads.shp")

# %% [markdown]
# ## Plot number of Events

# %% [markdown]
# ### Variables

# %%
#Plot the frequency of date occurences
event_counts_df = events_df["Date"].value_counts().reset_index()

#Dict to save the following format Date: Freq
event_series = {}

# %% [markdown]
# ### Merge Datasets on Date

# %%
#Rename the columns
event_counts_df = event_counts_df.rename(index=str, columns={"index": "Date", "Date": "EventFrequency"})

# %%
#Merge the dataframes on Date
event_counts_df = pd.merge(gvb_df, event_counts_df, on=["Date"], how="outer")

#Only select the date and freq column
event_counts_df = event_counts_df[["Date", "EventFrequency"]]

#Drop the duplicate dates
event_counts_df = event_counts_df.drop_duplicates("Date")

#Fill NaN values with 0
event_counts_df = event_counts_df.fillna(0)

# %%
event_counts_df.head()
# Out:
#           Date  EventFrequency
# 0   2018-01-01             0.0
# 23  2018-02-01             0.0
# 46  2018-03-01             0.0
# 69  2018-04-01             0.0
# 92  2018-05-01             0.0

# %% [markdown]
# ### Change Date object to datetime

# %%
#Transform DF to dict
event_counts_dict = event_counts_df.to_dict("index")

#Saved the timestamp object with the freq in a new dict
for k, v in event_counts_dict.items():
    event_series[pd.Timestamp.strptime(v["Date"], "%Y-%m-%d")] = v["EventFrequency"]
    
#Transform dict to pandas Series
event_counts_series = pd.Series(event_series)

# %% [markdown]
# ### Plot

# %%
#Plot the series
event_counts_series.plot(title="Amserdam Events Counts")
plt.show()

# %% [markdown]
# ## Plot Coordinates Events
# Inspired by [this blog](https://towardsdatascience.com/geopandas-101-plot-any-data-with-a-latitude-and-longitude-on-a-map-98e01944b972)

# %% [markdown]
# ### Variables

# %%
#Coordinate System
crs = {"init": "epsg:4326"}

#Create a point object -> Point is essentially a single object that describes the longitude and latitude of a data-point
geometry = [Point(xy) for xy in zip(events_df["Longtitude"], events_df["Latitude"])]

# %% [markdown]
# ### DF Construction

# %%
events_geo_df = gpd.GeoDataFrame(events_df,
                         crs = crs,
                         geometry = geometry)

# %%
events_geo_df = events_geo_df[["Event", "geometry"]]

# %%
events_geo_df.head()
# Out:
#                  Event                    geometry
# 0  Springsnow Festival  POINT (4.894106 52.372638)
# 1  Springsnow Festival  POINT (4.894106 52.372638)
# 2     Holland Festival  POINT (4.885479 52.361582)
# 3     Holland Festival  POINT (4.885479 52.361582)
# 4     Holland Festival  POINT (4.885479 52.361582)

# %% [markdown]
# ### Map

# %%
event_names = events_geo_df.Event.unique()

# %%
fig,ax = plt.subplots(figsize = (15, 15))
road_map.plot(ax = ax, alpha = 0.4, color = "grey")
events_geo_df[events_geo_df["Event"].isin(names)].plot(ax = ax, markersize = 12, color = "green", marker = "o", 
                                                       label = "Event")
plt.legend(prop={"size": 15})
